# %%
import pandas as pd

df = pd.read_csv('cleanData2.csv', index_col=0)

# %%
df1 = pd.read_csv('Normalized1.csv', index_col=0)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.scatter(df['st_teff'], df['st_mass'])
ax.set_title('Temperature vs. Mass')
ax.set_xlabel('Temperature')
ax.set_ylabel('Mass')
# Out:
# Text(0, 0.5, 'Mass')

# %%
df.corr(method ='pearson')
# Out:
#                 pl_pnum  pl_orbper  pl_orbpererr1  pl_orbpererr2        ra  \
# pl_pnum        1.000000  -0.012394      -0.013104       0.013683  0.105325
# pl_orbper     -0.012394   1.000000       0.999168      -0.999325 -0.004064
# pl_orbpererr1 -0.013104   0.999168       1.000000      -0.998674 -0.003639
# pl_orbpererr2  0.013683  -0.999325      -0.998674       1.000000  0.003729
# ra             0.105325  -0.004064      -0.003639       0.003729  1.000000
# dec            0.108419  -0.037019      -0.034592       0.035733  0.459396
# st_dist       -0.029362  -0.016189      -0.013636       0.015338  0.271290
# st_disterr1   -0.135348  -0.009972      -0.008263       0.009481  0.187084
# st_disterr2    0.099476   0.006517       0.005095      -0.006392 -0.100095
# st_optmag      0.038583  -0.005262       0.001147       0.003247  0.503417
# st_teff       -0.044947  -0.018583      -0.017931       0.019929  0.019873
# ...

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
for i in df.itertuples():
    for j in range(len(i)):
        if(df[i][j]>0.4):
            print("i:",i,"j:",j,"df[i][j]",df[i][j])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
print(x)
# Out:
#                 pl_pnum  pl_orbper  pl_orbpererr1  pl_orbpererr2        ra  \
# pl_pnum        1.000000  -0.012394      -0.013104       0.013683  0.105325
# pl_orbper     -0.012394   1.000000       0.999168      -0.999325 -0.004064
# pl_orbpererr1 -0.013104   0.999168       1.000000      -0.998674 -0.003639
# pl_orbpererr2  0.013683  -0.999325      -0.998674       1.000000  0.003729
# ra             0.105325  -0.004064      -0.003639       0.003729  1.000000
# dec            0.108419  -0.037019      -0.034592       0.035733  0.459396
# st_dist       -0.029362  -0.016189      -0.013636       0.015338  0.271290
# st_disterr1   -0.135348  -0.009972      -0.008263       0.009481  0.187084
# st_disterr2    0.099476   0.006517       0.005095      -0.006392 -0.100095
# st_optmag      0.038583  -0.005262       0.001147       0.003247  0.503417
# st_teff       -0.044947  -0.018583      -0.017931       0.019929  0.019873
# ...

# %%
df.columns=df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['pl_name', 'pl_discmethod', 'pl_pnum', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'ra_str', 'ra', 'dec_str', 'dec', 'st_dist',
#        'st_disterr1', 'st_disterr2', 'st_optmag', 'st_optband', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_mass', 'st_masserr1', 'st_masserr2',
#        'st_rad', 'st_raderr1', 'st_raderr2'],
#       dtype='object')

# %%
plt.figure(figsize=(100,80))
df['st_optmag'].plot()
plt.ylabel("Frequency")
plt.xlabel("time count")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import seaborn as sns

plt.subplots(figsize=(15,6))
sns.countplot('st_optband',data=df,edgecolor=sns.color_palette('bright',10))
plt.xticks(rotation=90)
plt.title('Optical Magnitude Band')
plt.show()

# %%
plt.subplots(figsize=(15,6))
sns.countplot('pl_discmethod',data=df,palette="PuBuGn_d",edgecolor=sns.color_palette('bright',10))
plt.xticks(rotation=90)
plt.title('Optical Magnitude Band')
plt.xlabel('Type Of Discovery Method')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(df['ra'],df['st_optmag'],color="orange")
plt.plot(plt.np.unique(df['ra']), plt.np.poly1d(plt.np.polyfit(df['ra'], df['st_optmag'], 1))(plt.np.unique(df['ra'])))

# %%
plt.figure(num=None, figsize=(8, 15), dpi=80, facecolor='w', edgecolor='k')
sns.barplot(y='ra', x='st_optmag', data=df, estimator=plt.np.median)
plt.show()

# %%
#df2=df['ra','dec','st_dist','st_mass','st_rad']

plt.subplot(2,2,1)
sns.boxplot(data=df,y="st_optmag",x="ra")
plt.title("Min Temparature Monthwise")
plt.xlabel("Month")
plt.ylabel("Temparature")
# Out:
# Text(0, 0.5, 'Temparature')

# %%
lst=list((df['st_mass']-df['st_mass'].mean())/df['st_mass'].std())
df['norm_int_rate']=lst
df.norm_int_rate.plot(kind='kde')

# %%
lst=list((df['pl_orbper']-df['pl_orbper'].mean())/df['pl_orbper'].std())
df['norm_int_rate']=lst
df.norm_int_rate.plot(kind='kde')

# %%
lst=list((df['st_dist']-df['st_dist'].mean())/df['st_dist'].std())
df['norm_int_rate']=lst
df.norm_int_rate.plot(kind='kde')

# %%
lst=list((df['st_optmag']-df['st_optmag'].mean())/df['st_optmag'].std())
df['norm_int_rate']=lst
df.norm_int_rate.plot(kind='kde')

# %%
lst=list((df['st_teff']-df['st_teff'].mean())/df['st_teff'].std())
df['norm_int_rate']=lst
df.norm_int_rate.plot(kind='kde')

# %%
lst=list((df['st_rad']-df['st_rad'].mean())/df['st_rad'].std())
df['norm_int_rate']=lst
df.norm_int_rate.plot(kind='kde')

# %%
lst=list((df['st_mass']-min(df['st_mass']))/(max(df['st_mass'])-min(df['st_mass'])))
#(df['st_mass']-min(df['st_mass']))/(max(df['st_mass'])-min(df['st_mass']))
df['norm_int_rate']=lst
df.norm_int_rate.plot(kind='kde')

# %%
#df['st_mass_norm']
from sklearn import preprocessing
import numpy as np
x_array = np.array(df['st_dist'])
df['st_mass_norm'] = preprocessing.StandardScaler([x_array])

# %%
lst=list((df['pl_orbper']-min(df['pl_orbper']))/(max(df['pl_orbper'])-min(df['pl_orbper'])))
df['norm_int_rate']=lst
df.norm_int_rate.plot(kind='kde')

# %%
lst=list((df['st_dist']-min(df['st_dist']))/(max(df['st_dist'])-min(df['st_dist'])))
df['norm_int_rate']=lst
df.norm_int_rate.plot(kind='kde')

# %%
df.describe()
# Out:
#            pl_pnum     pl_orbper  pl_orbpererr1  pl_orbpererr2           ra  \
# count  3372.000000  3.372000e+03   3.372000e+03   3.372000e+03  3372.000000
# mean      1.765421  2.788309e+03   1.227448e+03  -1.283515e+03   259.033885
# std       1.120909  1.262501e+05   6.296325e+04   6.322793e+04    75.300217
# min       1.000000  9.070629e-02   0.000000e+00  -3.650000e+06     0.362142
# 25%       1.000000  4.849946e+00   1.600000e-05  -8.851000e-04   281.482749
# 50%       1.000000  1.317929e+01   8.370000e-05  -8.405000e-05   289.080595
# 75%       2.000000  4.961134e+01   8.881250e-04  -1.600000e-05   294.441763
# max       7.000000  7.300000e+06   3.650000e+06   0.000000e+00   359.974304
#
#                dec      st_dist  st_disterr1  st_disterr2    st_optmag  \
# count  3372.000000  3372.000000  3372.000000  3372.000000  3372.000000
# mean     29.515197   670.480302    95.208302   -65.690520    12.942483
# ...

# %%
df['pl_orbper_norm'] = preprocessing.StandardScaler(np.array(df['pl_orbper']))

# %%
df.columns
# Out:
# Index(['pl_name', 'pl_discmethod', 'pl_pnum', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'ra_str', 'ra', 'dec_str', 'dec', 'st_dist',
#        'st_disterr1', 'st_disterr2', 'st_optmag', 'st_optband', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_mass', 'st_masserr1', 'st_masserr2',
#        'st_rad', 'st_raderr1', 'st_raderr2', 'norm_int_rate', 'st_mass_norm',
#        'pl_orbper_norm'],
#       dtype='object')

# %%
df['st_mass_norm'] = preprocessing.StandardScaler(np.array(df['st_mass']))

# %%
df['st_teff_norm'] = preprocessing.StandardScaler(np.array(df['st_teff']))

# %%
df3=df.drop(['norm_int_rate'],axis=1)

# %%
df3.to_csv("NormalHoke.csv")

# %%
import seaborn as sns

sns.heatmap(df.corr())

# %%
import numpy.random as random

data=list(df.st_mass)
data.sort()
norm=random.normal(0,2,len(data))
norm.sort()
plt.figure(figsize=(12,8),facecolor='1.0') 

plt.plot(norm,data,"o")


z = np.polyfit(norm,data, 1)
p = np.poly1d(z)
plt.plot(norm,p(norm),"k--", linewidth=2)
plt.title("Normal Q-Q plot", size=28)
plt.xlabel("Theoretical quantiles", size=24)
plt.ylabel("Expreimental quantiles", size=24)
plt.tick_params(labelsize=16)
plt.show()

# %%
data=list(df.st_teff)
data.sort()
norm=random.normal(0,2,len(data))
norm.sort()
plt.figure(figsize=(12,8),facecolor='1.0') 

plt.plot(norm,data,"o")


z = np.polyfit(norm,data, 1)
p = np.poly1d(z)
plt.plot(norm,p(norm),"k--", linewidth=2)
plt.title("Normal Q-Q plot", size=28)
plt.xlabel("Theoretical quantiles", size=24)
plt.ylabel("Expreimental quantiles", size=24)
plt.tick_params(labelsize=16)
plt.show()

# %%
data=list(df.pl_orbper)
data.sort()
norm=random.normal(0,2,len(data))
norm.sort()
plt.figure(figsize=(12,8),facecolor='1.0') 

plt.plot(norm,data,"o")


z = np.polyfit(norm,data, 1)
p = np.poly1d(z)
plt.plot(norm,p(norm),"k--", linewidth=2)
plt.title("Normal Q-Q plot", size=28)
plt.xlabel("Theoretical quantiles", size=24)
plt.ylabel("Expreimental quantiles", size=24)
plt.tick_params(labelsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt1

plt1.pie(df['pl_pnum'].value_counts(),autopct ='% 1.1f %%', shadow = True, labels=['1','2','3','4','5','6','7'],explode=(0.0,0.0,0.1,0.1,0.1,0.2,0.3),radius=2) 
plt1.title("Number Of Planets In A System")
plt1.show()

# %%
plt1.scatter(df['st_mass'],df['st_teff'],color="lightgreen")
plt1.xlabel("Stellar Mass")
plt1.ylabel("Stellar Temperature")
plt1.title("Mass of Star vs. Temperature of Star")
# Out:
# Text(0.5, 1.0, 'Mass of Star vs. Temperature of Star')

# %%
plt1.scatter(df['st_optmag'],df['st_teff'],color="brown")
plt1.xlabel("Optical Magnitude")
plt1.ylabel("Stellar Temperature")
plt1.title("Luminosity vs. Temperature of Star")
# Out:
# Text(0.5, 1.0, 'Luminosity vs. Temperature of Star')
